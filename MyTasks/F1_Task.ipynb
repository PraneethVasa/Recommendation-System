# %% [markdown]
# ## ***Importing Required Libraries***

# %%
import pandas as pd
import numpy as np
from datetime import datetime
import random

# %% [markdown]
# ## ***SettingUp Constants***

# %%
alpha = 0.4
beta = 0.6
purchasing_power = 100.0
k = 7   # size of bundles
C_max = 100.0
theta = 1
gamma = 0.25
delta = 0.75
n_categories = 7  # max number of categories allowed per bundle
num_bundles = 4  # number of bundles

# %%
df = pd.read_csv('/content/sample_data_1000_C.csv')
df.head()
# Out:
#    CODEBELISTA  CODPRODUCTOSAP          DESCATEGORIA DESMARCA  PRECIOOFERTA  \
# 0     44109905       200112294            MAQUILLAJE   CYZONE          9.50
# 1     36949902       200086399            FRAGANCIAS     LBEL         19.95
# 2     49968221       200089498  TRATAMIENTO CORPORAL    ESIKA         36.90
# 3     46114531       210102388            BIJOUTERIE    ESIKA         59.90
# 4     50368645       210100620          COMPLEMENTOS   CYZONE         74.90
#
#   FECHAPROCESO
# 0   2023-02-09
# 1   2023-02-02
# 2   2023-02-10
# 3   2023-02-21
# 4   2023-03-01

# %% [markdown]
# ## ***Data Pre-processing***

# %%
#Renaming the columns
column_rename_map={
                "CODEBELISTA": "consultant_id",
                "CODPRODUCTOSAP": "product_id",
                "DESCATEGORIA": "category",
                "DESMARCA": "brand",
                "PRECIOOFERTA": "price",
                "FECHAPROCESO": "date"
            }
df.rename(columns=column_rename_map, inplace=True)
df.head()
# Out:
#    consultant_id  product_id              category   brand  price        date
# 0       44109905   200112294            MAQUILLAJE  CYZONE   9.50  2023-02-09
# 1       36949902   200086399            FRAGANCIAS    LBEL  19.95  2023-02-02
# 2       49968221   200089498  TRATAMIENTO CORPORAL   ESIKA  36.90  2023-02-10
# 3       46114531   210102388            BIJOUTERIE   ESIKA  59.90  2023-02-21
# 4       50368645   210100620          COMPLEMENTOS  CYZONE  74.90  2023-03-01

# %%
#Filling Null Values
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36310 entries, 0 to 36309
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   consultant_id  36310 non-null  int64
#  1   product_id     36310 non-null  int64
#  2   category       36228 non-null  object
#  3   brand          36310 non-null  object
#  4   price          36310 non-null  float64
#  5   date           36310 non-null  object
# dtypes: float64(1), int64(2), object(3)
# memory usage: 1.7+ MB

# %%
df['category'].fillna('OTHERS', inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36310 entries, 0 to 36309
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   consultant_id  36310 non-null  int64
#  1   product_id     36310 non-null  int64
#  2   category       36310 non-null  object
#  3   brand          36310 non-null  object
#  4   price          36310 non-null  float64
#  5   date           36310 non-null  object
# dtypes: float64(1), int64(2), object(3)
# memory usage: 1.7+ MB
# <ipython-input-29-d823663f0706>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['category'].fillna('OTHERS', inplace=True)

# %%
# Convert `date` column to datetime
df["date"] = pd.to_datetime(df["date"], errors="coerce")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36310 entries, 0 to 36309
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   consultant_id  36310 non-null  int64
#  1   product_id     36310 non-null  int64
#  2   category       36310 non-null  object
#  3   brand          36310 non-null  object
#  4   price          36310 non-null  float64
#  5   date           36310 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), float64(1), int64(2), object(2)
# memory usage: 1.7+ MB

# %%
# Perform daily aggregation
group_by_columns = ["consultant_id", "date"]
daily_agg = df.groupby(group_by_columns, as_index=False).agg({
    "product_id": "count",
    "price": "sum"
})

# Rename columns for clarity
daily_agg.rename(columns={
    "product_id": "frequency",
    "price": "daily_total_spent"
}, inplace=True)

daily_agg.head()
# Out:
#    consultant_id       date  frequency  daily_total_spent
# 0        3441296 2022-12-27         10             263.40
# 1        3441296 2023-02-07          8             273.30
# 2        3441296 2023-02-15          1              23.90
# 3        3441296 2023-02-28          7             261.45
# 4        3441296 2023-04-11         17             391.10

# %%
# Calculate IQR for daily_total_spent
Q1 = np.percentile(daily_agg["daily_total_spent"], 25)
Q3 = np.percentile(daily_agg["daily_total_spent"], 75)
IQR = Q3 - Q1

# Add average purchasing power (Q3) as a new column
daily_agg["average_purchasing_power"] = Q3

# %%
# Merge the daily aggregates back into the original DataFrame
df = pd.merge(df, daily_agg, on=group_by_columns, how="left")
df.head()
# Out:
#    consultant_id  product_id              category   brand  price       date  \
# 0       44109905   200112294            MAQUILLAJE  CYZONE   9.50 2023-02-09
# 1       36949902   200086399            FRAGANCIAS    LBEL  19.95 2023-02-02
# 2       49968221   200089498  TRATAMIENTO CORPORAL   ESIKA  36.90 2023-02-10
# 3       46114531   210102388            BIJOUTERIE   ESIKA  59.90 2023-02-21
# 4       50368645   210100620          COMPLEMENTOS  CYZONE  74.90 2023-03-01
#
#    frequency  daily_total_spent  average_purchasing_power
# 0         17             427.40                   430.195
# 1         16             403.90                   430.195
# 2         21             406.30                   430.195
# 3         11             469.10                   430.195
# 4          5             202.55                   430.195

# %%
# Calculate recency in days
current_date = datetime.now()
df["recency"] = (current_date - df["date"]).dt.days
df.head()
# Out:
#    consultant_id  product_id              category   brand  price       date  \
# 0       44109905   200112294            MAQUILLAJE  CYZONE   9.50 2023-02-09
# 1       36949902   200086399            FRAGANCIAS    LBEL  19.95 2023-02-02
# 2       49968221   200089498  TRATAMIENTO CORPORAL   ESIKA  36.90 2023-02-10
# 3       46114531   210102388            BIJOUTERIE   ESIKA  59.90 2023-02-21
# 4       50368645   210100620          COMPLEMENTOS  CYZONE  74.90 2023-03-01
#
#    frequency  daily_total_spent  average_purchasing_power  recency
# 0         17             427.40                   430.195      688
# 1         16             403.90                   430.195      695
# 2         21             406.30                   430.195      687
# 3         11             469.10                   430.195      676
# 4          5             202.55                   430.195      668

# %%
# Normalize frequency
freq_min = df["frequency"].min()
freq_max = df["frequency"].max()

if freq_min != freq_max:
    df["frequency_normalized"] = (df["frequency"] - freq_min) / (freq_max - freq_min)
else:
    df["frequency_normalized"] = 0.5

# %%
# Normalize recency
rec_min = df["recency"].min()
rec_max = df["recency"].max()

if rec_min != rec_max:
    df["recency_normalized"] = (df["recency"] - rec_min) / (rec_max - rec_min)
else:
    df["recency_normalized"] = 0.5

# %%
# Consultant-level metrics
df["total_spent"] = df.groupby("consultant_id")["price"].transform("sum")
df["purchase_frequency"] = df.groupby("consultant_id")["product_id"].transform("count")
df["unique_products"] = df.groupby("consultant_id")["product_id"].transform("nunique")

# %%
df.head()
# Out:
#    consultant_id  product_id              category   brand  price       date  \
# 0       44109905   200112294            MAQUILLAJE  CYZONE   9.50 2023-02-09
# 1       36949902   200086399            FRAGANCIAS    LBEL  19.95 2023-02-02
# 2       49968221   200089498  TRATAMIENTO CORPORAL   ESIKA  36.90 2023-02-10
# 3       46114531   210102388            BIJOUTERIE   ESIKA  59.90 2023-02-21
# 4       50368645   210100620          COMPLEMENTOS  CYZONE  74.90 2023-03-01
#
#    frequency  daily_total_spent  average_purchasing_power  recency  \
# 0         17             427.40                   430.195      688
# 1         16             403.90                   430.195      695
# 2         21             406.30                   430.195      687
# 3         11             469.10                   430.195      676
# 4          5             202.55                   430.195      668
#
#    frequency_normalized  recency_normalized  total_spent  purchase_frequency  \
# 0              0.280702            0.919946      4548.33                 159
# 1              0.263158            0.929444      3459.60                 116
# 2              0.350877            0.918589      3674.05                 137
# 3              0.175439            0.903664      6815.04                 161
# 4              0.070175            0.892809      9109.95                 482
#
#    unique_products
# 0              125
# 1              102
# 2              120
# 3              143
# 4              280

# %%
df.to_csv("preprocessed_data_1000_C.csv", index=False)

# %% [markdown]
# ## ***Combined Score for each row based on normalized frequency and recency***

# %%
df = pd.read_csv('/content/preprocessed_data_1000_C.csv')

def normalize(value, min_value, max_value):
    if min_value == max_value:
        return 0
    return (value - min_value) / (max_value - min_value)

min_f = df['purchase_frequency'].min()
max_f = df['purchase_frequency'].max()
min_r = df['recency'].min()
max_r = df['recency'].max()

df['normalized_f'] = df['purchase_frequency'].apply(lambda x: normalize(x, min_f, max_f))
df['normalized_r'] = df['recency'].apply(lambda x: normalize(x, min_r, max_r))
df['combined_score'] = (alpha * df['normalized_f']) + (beta * df['normalized_r'])
df.head()
# Out:
#    consultant_id  product_id              category   brand  price        date  \
# 0       44109905   200112294            MAQUILLAJE  CYZONE   9.50  2023-02-09
# 1       36949902   200086399            FRAGANCIAS    LBEL  19.95  2023-02-02
# 2       49968221   200089498  TRATAMIENTO CORPORAL   ESIKA  36.90  2023-02-10
# 3       46114531   210102388            BIJOUTERIE   ESIKA  59.90  2023-02-21
# 4       50368645   210100620          COMPLEMENTOS  CYZONE  74.90  2023-03-01
#
#    frequency  daily_total_spent  average_purchasing_power  recency  \
# 0         17             427.40                   430.195      688
# 1         16             403.90                   430.195      695
# 2         21             406.30                   430.195      687
# 3         11             469.10                   430.195      676
# 4          5             202.55                   430.195      668
#
#    frequency_normalized  recency_normalized  total_spent  purchase_frequency  \
# 0              0.280702            0.919946      4548.33                 159
# 1              0.263158            0.929444      3459.60                 116
# 2              0.350877            0.918589      3674.05                 137
# 3              0.175439            0.903664      6815.04                 161
# 4              0.070175            0.892809      9109.95                 482
#
#    unique_products  normalized_f  normalized_r  combined_score
# 0              125      0.208995      0.919946        0.635565
# 1              102      0.152116      0.929444        0.618513
# 2              120      0.179894      0.918589        0.623111
# 3              143      0.211640      0.903664        0.626854
# 4              280      0.636243      0.892809        0.790183

# %%
def select_anchor_product(df):
        """
        Selects the product with the maximum 'combined_score'.
        """
        return df.loc[df['combined_score'].idxmax()]

def generate_candidates(bundle, df):
        """
        Returns products not already in the bundle.
        """
        bundle_product_ids = {p['product_id'] for p in bundle}
        return df[~df['product_id'].isin(bundle_product_ids)]

def category_score(product, bundle):
    """
    Returns 1 if product's category is in the current bundle, else 0.
    """
    return 1 if product['category'] in [b['category'] for b in bundle] else 0

def business_score(product):
    """
    Placeholder for any advanced logic; returns a random score for now.
    """
    return random.random()

# %%
def score_candidates(candidates, bundle):
        """
        Calculates the composite score for candidates.

        Parameters
        ----------
        candidates : pd.DataFrame
            The candidate products.
        bundle : list
            Current bundle (list of dicts or rows).

        Returns
        -------
        pd.DataFrame
            Updated candidates DataFrame with a 'score' column.
        """
        candidates = candidates.copy()
        candidates['category_score'] = candidates.apply(lambda p: category_score(p, bundle), axis=1)
        candidates['business_score'] = candidates.apply(business_score, axis=1)
        candidates['score'] = gamma * candidates['category_score'] + delta * candidates['business_score']
        return candidates

def build_bundle(df, anchor_product, purchasing_power, k, C_max, theta, n_categories):
        """
        Constructs the bundle starting with anchor_product.

        Parameters
        ----------
        df : pd.DataFrame
            DataFrame containing product information.
        anchor_product : pd.Series or dict
            The product chosen as the anchor.
        purchasing_power : float
            Unused in this example, but could factor into logic.
        k : int
            Max size of the bundle.
        C_max : float
            Maximum cost threshold for the bundle.
        theta : float
            Threshold multiplier for item price acceptance.
        n_categories : int
            Number of distinct categories allowed in the bundle.

        Returns
        -------
        list
            A list (bundle) containing the chosen products.
        """
        bundle = [anchor_product]
        current_total_cost = anchor_product['price']
        categories_in_bundle = {anchor_product['category']}

        # Exclude the anchor product from candidates
        candidates = df[df['product_id'] != anchor_product['product_id']]
        candidates = score_candidates(candidates, bundle)
        candidates = candidates[candidates['price'] <= theta * C_max].sort_values(by='score', ascending=False)

        for _, candidate in candidates.iterrows():
            if len(bundle) >= k:
                break
            if candidate['category'] in categories_in_bundle:
                # n_categories = 1 => do not add new categories
                if current_total_cost + candidate['price'] <= C_max:
                    bundle.append(candidate)
                    current_total_cost += candidate['price']
                    # We do not add a new category if n_categories=1
            else:
                # If your logic allows new category, incorporate that here
                pass

        return bundle

# %%
bundles = []
for consultant_id, group in df.groupby("consultant_id"):
            for bundle_index in range(num_bundles):
                anchor_product = select_anchor_product(group)
                bundle = build_bundle(
                    group,
                    anchor_product,
                    purchasing_power,  # from config
                    k,
                    C_max,
                    theta,
                    n_categories
                )
                unique_bundle_id = f"{consultant_id}_Bundle_{bundle_index+1}"
                for idx, product in enumerate(bundle):
                    product_copy = product.copy()
                    product_copy["consultant_id"] = consultant_id
                    product_copy["bundle_id"] = unique_bundle_id
                    product_copy["is_anchor"] = 1 if idx == 0 else 0
                    bundles.append(product_copy)

# %%
bundles
# Out:
# [consultant_id                        3441296
#  product_id                         200095159
#  category                    CUIDADO PERSONAL
#  brand                                  ESIKA
#  price                                   7.38
#  date                              2022-12-27
#  frequency                                 10
#  daily_total_spent                      263.4
#  average_purchasing_power             430.195
#  recency                                  732
#  frequency_normalized                0.157895
#  recency_normalized                  0.979647
#  total_spent                          7206.76
#  purchase_frequency                       261
#  unique_products                          194
#  normalized_f                        0.343915
#  normalized_r                        0.979647
#  combined_score                      0.725354
#  bundle_id                   3441296_Bundle_1
#  is_anchor                                  1
#  Name: 1793, dtype: object,
#  consultant_id                        3441296
#  product_id                         200108807
#  category                    CUIDADO PERSONAL
#  brand                                  ESIKA
#  price                                   7.38
#  date                              2022-12-27
#  frequency                                 10
#  daily_total_spent                      263.4
#  average_purchasing_power             430.195
#  recency                                  732
#  frequency_normalized                0.157895
#  recency_normalized                  0.979647
#  total_spent                          7206.76
#  purchase_frequency                       261
#  unique_products                          194
#  normalized_f                        0.343915
#  normalized_r                        0.979647
#  combined_score                      0.725354
#  category_score                             1
#  business_score                      0.921432
#  score                               0.941074
#  bundle_id                   3441296_Bundle_1
#  is_anchor                                  0
#  Name: 4744, dtype: object,
#  consultant_id                        3441296
#  product_id                         200095465
#  category                    CUIDADO PERSONAL
#  brand                                  ESIKA
#  price                                   11.9
#  date                              2023-06-08
#  frequency                                 16
#  daily_total_spent                      385.9
#  average_purchasing_power             430.195
#  recency                                  569
#  frequency_normalized                0.263158
#  recency_normalized                   0.75848
#  total_spent                          7206.76
#  purchase_frequency                       261
#  unique_products                          194
#  normalized_f                        0.343915
#  normalized_r                         0.75848
#  combined_score                      0.592654
#  category_score                             1
#  business_score                      0.897779
#  score                               0.923334
#  bundle_id                   3441296_Bundle_1
#  is_anchor                                  0
#  Name: 22714, dtype: object,
#  consultant_id                        3441296
#  product_id                         200103025
#  category                    CUIDADO PERSONAL
#  brand                                  ESIKA
#  price                                  24.98
#  date                              2023-08-15
#  frequency                                 11
#  daily_total_spent                     156.66
#  average_purchasing_power             430.195
#  recency                                  501
#  frequency_normalized                0.175439
#  recency_normalized                  0.666214
#  total_spent                          7206.76
#  purchase_frequency                       261
#  unique_products                          194
#  normalized_f                        0.343915
#  normalized_r                        0.666214
#  combined_score                      0.537295
#  category_score                             1
#  business_score                       0.88335
#  score                               0.912513
#  bundle_id                   3441296_Bundle_1
#  is_anchor                                  0
#  Name: 9107, dtype: object,
#  consultant_id                        3441296
#  product_id                         200115451
#  category                    CUIDADO PERSONAL
#  brand                                  ESIKA
#  price                                   18.3
#  date                              2024-03-20
#  frequency                                  7
#  daily_total_spent                      183.5
#  average_purchasing_power             430.195
#  recency                                  283
#  frequency_normalized                0.105263
#  recency_normalized                  0.370421
#  total_spent                          7206.76
#  purchase_frequency                       261
#  unique_products                          194
#  normalized_f                        0.343915
#  normalized_r                        0.370421
#  combined_score                      0.359819
#  category_score                             1
#  business_score                      0.879163
#  score                               0.909372
#  bundle_id                   3441296_Bundle_1
#  is_anchor                                  0
#  Name: 20479, dtype: object,
#  consultant_id                        3441296
#  product_id                         200078931
#  category                    CUIDADO PERSONAL
#  brand                                  ESIKA
#  price                                  13.27
#  date                              2023-06-08
#  frequency                                 16
#  daily_total_spent                      385.9
#  average_purchasing_power             430.195
#  recency                                  569
#  frequency_normalized                0.263158
#  recency_normalized                   0.75848
#  total_spent                          7206.76
#  purchase_frequency                       261
#  unique_products                          194
#  normalized_f                        0.343915
#  normalized_r                         0.75848
#  combined_score                      0.592654
#  category_score                             1
#  business_score                      0.857582
#  score                               0.893186
#  bundle_id                   3441296_Bundle_1
#  is_anchor                                  0
#  Name: 18988, dtype: object,
#  consultant_id                        3441296
#  product_id                         200105195
#  category                    CUIDADO PERSONAL
#  brand                                  ESIKA
#  price                                   7.38
#  date                              2024-07-03
#  frequency                                 16
#  daily_total_spent                     354.53
#  average_purchasing_power             430.195
#  recency                                  178
#  frequency_normalized                0.263158
#  recency_normalized                  0.227951
#  total_spent                          7206.76
#  purchase_frequency                       261
#  unique_products                          194
#  normalized_f                        0.343915
#  normalized_r                        0.227951
#  combined_score                      0.274337
#  category_score                             1
#  business_score                      0.846935
#  score                               0.885201
#  bundle_id                   3441296_Bundle_1
#  is_anchor                                  0
#  Name: 35403, dtype: object,
#  consultant_id                        3441296
#  product_id                         200095159
#  category                    CUIDADO PERSONAL
#  brand                                  ESIKA
#  price                                   7.38
#  date                              2022-12-27
#  frequency                                 10
#  daily_total_spent                      263.4
#  average_purchasing_power             430.195
#  recency                                  732
#  frequency_normalized                0.157895
#  recency_normalized                  0.979647
#  total_spent                          7206.76
#  purchase_frequency                       261
#  unique_products                          194
#  normalized_f                        0.343915
#  normalized_r                        0.979647
#  combined_score                      0.725354
#  bundle_id                   3441296_Bundle_2
#  is_anchor                                  1
#  Name: 1793, dtype: object,
#  consultant_id                        3441296
#  product_id                         200095420
#  category                    CUIDADO PERSONAL
#  brand                                  ESIKA
#  price                                   7.38
#  date                              2023-08-15
#  frequency                                 11
#  daily_total_spent                     156.66
#  average_purchasing_power             430.195
#  recency                                  501
#  frequency_normalized                0.175439
#  recency_normalized                  0.666214
#  total_spent                          7206.76
#  purchase_frequency                       261
#  unique_products                          194
#  normalized_f                        0.343915
#  normalized_r                        0.666214
#  combined_score                      0.537295
#  category_score                             1
#  business_score                      0.999504
#  score                               0.999628
#  bundle_id                   3441296_Bundle_2
#  is_anchor                                  0
#  Name: 13374, dtype: object,
#  consultant_id                        3441296
#  product_id                         200105188
#  category                    CUIDADO PERSONAL
#  brand                                  ESIKA
#  price                                   7.38
#  date                              2023-08-15
#  frequency                                 11
#  daily_total_spent                     156.66
#  average_purchasing_power             430.195
#  recency                                  501
#  frequency_normalized                0.175439
#  recency_normalized                  0.666214
#  total_spent                          7206.76
#  purchase_frequency                       261
#  unique_products                          194
#  normalized_f                        0.343915
#  normalized_r                        0.666214
#  combined_score                      0.537295
#  category_score                             1
#  business_score                      0.994874
#  score                               0.996155
#  bundle_id                   3441296_Bundle_2
#  is_anchor                                  0
#  Name: 5064, dtype: object,
#  consultant_id                        3441296
#  product_id                         200103025
#  category                    CUIDADO PERSONAL
#  brand                                  ESIKA
#  price                                  21.98
#  date                              2024-08-13
#  frequency                                 11
#  daily_total_spent                     344.28
#  average_purchasing_power             430.195
#  recency                                  137
#  frequency_normalized                0.175439
#  recency_normalized                   0.17232
#  total_spent                          7206.76
#  purchase_frequency                       261
#  unique_products                          194
#  normalized_f                        0.343915
#  normalized_r                         0.17232
#  combined_score                      0.240958
#  category_score                             1
#  business_score                      0.959799
#  score                               0.969849
#  bundle_id                   3441296_Bundle_2
#  is_anchor                                  0
#  Name: 12044, dtype: object,
#  consultant_id                        3441296
#  product_id                         200112361
#  category                    CUIDADO PERSONAL
#  brand                                  ESIKA
#  price                                   25.9
#  date                              2023-12-11
#  frequency                                 10
#  daily_total_spent                     266.22
#  average_purchasing_power             430.195
#  recency                                  383
#  frequency_normalized                0.157895
#  recency_normalized                  0.506106
#  total_spent                          7206.76
#  purchase_frequency                       261
#  unique_products                          194
#  normalized_f                        0.343915
#  normalized_r                        0.506106
#  combined_score                       0.44123
#  category_score                             1
#  business_score                       0.90728
#  score                                0.93046
#  bundle_id                   3441296_Bundle_2
#  is_anchor                                  0
#  Name: 15256, dtype: object,
#  consultant_id                        3441296
#  product_id                         200103448
#  category                    CUIDADO PERSONAL
#  brand                                  ESIKA
#  price                                   7.38
#  date                              2024-07-03
#  frequency                                 16
#  daily_total_spent                     354.53
#  average_purchasing_power             430.195
#  recency                                  178
#  frequency_normalized                0.263158
#  recency_normalized                  0.227951
#  total_spent                          7206.76
#  purchase_frequency                       261
#  unique_products                          194
#  normalized_f                        0.343915
#  normalized_r                        0.227951
#  combined_score                      0.274337
#  category_score                             1
#  business_score                      0.906653
#  score                                0.92999
#  bundle_id                   3441296_Bundle_2
#  is_anchor                                  0
#  Name: 21152, dtype: object,
#  consultant_id                        3441296
#  product_id                         200103028
#  category                    CUIDADO PERSONAL
#  brand                                  ESIKA
#  price                                  16.64
#  date                              2024-07-23
#  frequency                                  8
#  daily_total_spent                     262.87
#  average_purchasing_power             430.195
#  recency                                  158
#  frequency_normalized                0.122807
#  recency_normalized                  0.200814
#  total_spent                          7206.76
#  purchase_frequency                       261
#  unique_products                          194
#  normalized_f                        0.343915
#  normalized_r                        0.200814
#  combined_score                      0.258055
#  category_score                             1
#  business_score                      0.838307
#  score                               0.878731
#  bundle_id                   3441296_Bundle_2
#  is_anchor                                  0
#  Name: 26232, dtype: object,
#  consultant_id                        3441296
#  product_id                         200095159
#  category                    CUIDADO PERSONAL
#  brand                                  ESIKA
#  price                                   7.38
#  date                              2022-12-27
#  frequency                                 10
#  daily_total_spent                      263.4
#  average_purchasing_power             430.195
#  recency                                  732
#  frequency_normalized                0.157895
#  recency_normalized                  0.979647
#  total_spent                          7206.76
#  purchase_frequency                       261
#  unique_products                          194
#  normalized_f                        0.343915
#  normalized_r                        0.979647
#  combined_score                      0.725354
#  bundle_id                   3441296_Bundle_3
#  is_anchor                                  1
#  Name: 1793, dtype: object,
#  consultant_id                        3441296
#  product_id                         200078924
#  category                    CUIDADO PERSONAL
#  brand                                  ESIKA
#  price                                   16.9
#  date                              2024-07-03
#  frequency                                 16
#  daily_total_spent                     354.53
#  average_purchasing_power             430.195
#  recency                                  178
#  frequency_normalized                0.263158
#  recency_normalized                  0.227951
#  total_spent                          7206.76
#  purchase_frequency                       261
#  unique_products                          194
#  normalized_f                        0.343915
#  normalized_r                        0.227951
#  combined_score                      0.274337
#  category_score                             1
#  business_score                      0.927455
#  score                               0.945592
#  bundle_id                   3441296_Bundle_3
#  is_anchor                                  0
#  Name: 3122, dtype: object,
#  consultant_id                        3441296
#  product_id                         200095465
#  category                    CUIDADO PERSONAL
#  brand                                  ESIKA
#  price                                   11.9
#  date                              2023-06-08
#  frequency                                 16
#  daily_total_spent                      385.9
#  average_purchasing_power             430.195
#  recency                                  569
#  frequency_normalized                0.263158
#  recency_normalized                   0.75848
#  total_spent                          7206.76
#  purchase_frequency                       261
#  unique_products                          194
#  normalized_f                        0.343915
#  normalized_r                         0.75848
#  combined_score                      0.592654
#  category_score                             1
#  business_score                       0.91086
#  score                               0.933145
#  bundle_id                   3441296_Bundle_3
#  is_anchor                                  0
#  Name: 22714, dtype: object,
#  consultant_id                        3441296
#  product_id                         200082652
#  category                    CUIDADO PERSONAL
#  brand                                  ESIKA
#  price                                   31.9
#  date                              2022-12-27
#  frequency                                 10
#  daily_total_spent                      263.4
#  average_purchasing_power             430.195
#  recency                                  732
#  frequency_normalized                0.157895
#  recency_normalized                  0.979647
#  total_spent                          7206.76
#  purchase_frequency                       261
#  unique_products                          194
#  normalized_f                        0.343915
#  normalized_r                        0.979647
#  combined_score                      0.725354
#  category_score                             1
#  business_score                      0.894878
#  score                               0.921158
#  bundle_id                   3441296_Bundle_3
#  is_anchor                                  0
#  Name: 27338, dtype: object,
#  consultant_id                        3441296
#  product_id                         200108807
#  category                    CUIDADO PERSONAL
#  brand                                  ESIKA
#  price                                   7.38
#  date                              2024-07-03
#  frequency                                 16
#  daily_total_spent                     354.53
#  average_purchasing_power             430.195
#  recency                                  178
#  frequency_normalized                0.263158
#  recency_normalized                  0.227951
#  total_spent                          7206.76
#  purchase_frequency                       261
#  unique_products                          194
#  normalized_f                        0.343915
#  normalized_r                        0.227951
#  combined_score                      0.274337
#  category_score                             1
#  business_score                       0.87551
#  score                               0.906633
#  bundle_id                   3441296_Bundle_3
#  is_anchor                                  0
#  Name: 3149, dtype: object,
#  consultant_id                        3441296
#  product_id                         200090337
#  category                    CUIDADO PERSONAL
#  brand                                  ESIKA
#  price                                   23.9
#  date                              2023-04-11
#  frequency                                 17
#  daily_total_spent                      391.1
#  average_purchasing_power             430.195
#  recency                                  627
#  frequency_normalized                0.280702
#  recency_normalized                  0.837178
#  total_spent                          7206.76
#  purchase_frequency                       261
#  unique_products                          194
#  normalized_f                        0.343915
#  normalized_r                        0.837178
#  combined_score                      0.639873
#  category_score                             1
#  business_score                       0.82918
#  score                               0.871885
#  bundle_id                   3441296_Bundle_3
#  is_anchor                                  0
#  Name: 28897, dtype: object,
#  consultant_id                        3441296
#  product_id                         200095159
#  category                    CUIDADO PERSONAL
#  brand                                  ESIKA
#  price                                   7.38
#  date                              2022-12-27
#  frequency                                 10
#  daily_total_spent                      263.4
#  average_purchasing_power             430.195
#  recency                                  732
#  frequency_normalized                0.157895
#  recency_normalized                  0.979647
#  total_spent                          7206.76
#  purchase_frequency                       261
#  unique_products                          194
#  normalized_f                        0.343915
#  normalized_r                        0.979647
#  combined_score                      0.725354
#  bundle_id                   3441296_Bundle_4
#  is_anchor                                  1
#  Name: 1793, dtype: object,
#  consultant_id                        3441296
#  product_id                         200095430
#  category                    CUIDADO PERSONAL
#  brand                                 CYZONE
#  price                                   6.69
#  date                              2023-04-11
#  frequency                                 17
#  daily_total_spent                      391.1
#  average_purchasing_power             430.195
#  recency                                  627
#  frequency_normalized                0.280702
#  recency_normalized                  0.837178
#  total_spent                          7206.76
#  purchase_frequency                       261
#  unique_products                          194
#  normalized_f                        0.343915
#  normalized_r                        0.837178
#  combined_score                      0.639873
#  category_score                             1
#  business_score                      0.998449
#  score                               0.998837
#  bundle_id                   3441296_Bundle_4
#  is_anchor                                  0
#  Name: 10832, dtype: object,
#  consultant_id                        3441296
#  product_id                         200112361
#  category                    CUIDADO PERSONAL
#  brand                                  ESIKA
#  price                                   25.9
#  date                              2023-10-31
#  frequency                                  8
#  daily_total_spent                      245.5
#  average_purchasing_power             430.195
#  recency                                  424
#  frequency_normalized                0.122807
#  recency_normalized                  0.561737
#  total_spent                          7206.76
#  purchase_frequency                       261
#  unique_products                          194
#  normalized_f                        0.343915
#  normalized_r                        0.561737
#  combined_score                      0.474608
#  category_score                             1
#  business_score                      0.995082
#  score                               0.996312
#  bundle_id                   3441296_Bundle_4
#  is_anchor                                  0
#  Name: 13639, dtype: object,
#  consultant_id                        3441296
#  product_id                         200095382
#  category                    CUIDADO PERSONAL
#  brand                                  ESIKA
#  price                                   7.38
#  date                              2023-08-15
#  frequency                                 11
#  daily_total_spent                     156.66
#  average_purchasing_power             430.195
#  recency                                  501
#  frequency_normalized                0.175439
#  recency_normalized                  0.666214
#  total_spent                          7206.76
#  purchase_frequency                       261
#  unique_products                          194
#  normalized_f                        0.343915
#  normalized_r                        0.666214
#  combined_score                      0.537295
#  category_score                             1
#  business_score                      0.983978
#  score                               0.987984
#  bundle_id                   3441296_Bundle_4
#  is_anchor                                  0
#  Name: 13380, dtype: object,
#  consultant_id                        3441296
#  product_id                         200090337
#  category                    CUIDADO PERSONAL
#  brand                                  ESIKA
#  price                                   23.9
#  date                              2023-04-11
#  frequency                                 17
#  daily_total_spent                      391.1
#  average_purchasing_power             430.195
#  recency                                  627
#  frequency_normalized                0.280702
#  recency_normalized                  0.837178
#  total_spent                          7206.76
#  purchase_frequency                       261
#  unique_products                          194
#  normalized_f                        0.343915
#  normalized_r                        0.837178
#  combined_score                      0.639873
#  category_score                             1
#  business_score                      0.958804
#  score                               0.969103
#  bundle_id                   3441296_Bundle_4
#  is_anchor                                  0
#  Name: 28897, dtype: object,
#  consultant_id                        3441296
#  product_id                         200103448
#  category                    CUIDADO PERSONAL
#  brand                                  ESIKA
#  price                                   7.38
#  date                              2024-07-03
#  frequency                                 16
#  daily_total_spent                     354.53
#  average_purchasing_power             430.195
#  recency                                  178
#  frequency_normalized                0.263158
#  recency_normalized                  0.227951
#  total_spent                          7206.76
#  purchase_frequency                       261
#  unique_products                          194
#  normalized_f                        0.343915
#  normalized_r                        0.227951
#  combined_score                      0.274337
#  category_score                             1
#  business_score                      0.950804
#  score                               0.963103
#  bundle_id                   3441296_Bundle_4
#  is_anchor                                  0
#  Name: 21152, dtype: object,
#  consultant_id                        3441296
#  product_id                         200105190
#  category                    CUIDADO PERSONAL
#  brand                                  ESIKA
#  price                                   7.38
#  date                              2023-08-15
#  frequency                                 11
#  daily_total_spent                     156.66
#  average_purchasing_power             430.195
#  recency                                  501
#  frequency_normalized                0.175439
#  recency_normalized                  0.666214
#  total_spent                          7206.76
#  purchase_frequency                       261
#  unique_products                          194
#  normalized_f                        0.343915
#  normalized_r                        0.666214
#  combined_score                      0.537295
#  category_score                             1
#  business_score                      0.921538
#  score                               0.941154
#  bundle_id                   3441296_Bundle_4
#  is_anchor                                  0
#  Name: 27995, dtype: object,
#  consultant_id                        4623541
#  product_id                         200101587
#  category                          MAQUILLAJE
#  brand                                  ESIKA
#  price                                   17.9
#  date                              2022-12-27
#  frequency                                 11
#  daily_total_spent                      133.3
#  average_purchasing_power             430.195
#  recency                                  732
#  frequency_normalized                0.175439
#  recency_normalized                  0.979647
#  total_spent                          4624.35
#  purchase_frequency                       181
#  unique_products                          151
#  normalized_f                        0.238095
#  normalized_r                        0.979647
#  combined_score                      0.683026
#  bundle_id                   4623541_Bundle_1
#  is_anchor                                  1
#  Name: 4569, dtype: object,
#  consultant_id                        4623541
#  product_id                         200108747
#  category                          MAQUILLAJE
#  brand                                  ESIKA
#  price                                   40.9
#  date                              2023-02-06
#  frequency                                 19
#  daily_total_spent                      558.3
#  average_purchasing_power             430.195
#  recency                                  691
#  frequency_normalized                0.315789
#  recency_normalized                  0.924016
#  total_spent                          4624.35
#  purchase_frequency                       181
#  unique_products                          151
#  normalized_f                        0.238095
#  normalized_r                        0.924016
#  combined_score                      0.649648
#  category_score                             1
#  business_score                      0.993739
#  score                               0.995304
#  bundle_id                   4623541_Bundle_1
#  is_anchor                                  0
#  Name: 29286, dtype: object,
#  consultant_id                        4623541
#  product_id                         200091455
#  category                          MAQUILLAJE
#  brand                                   LBEL
#  price                                   34.0
#  date                              2023-03-17
#  frequency                                 22
#  daily_total_spent                     476.75
#  average_purchasing_power             430.195
#  recency                                  652
#  frequency_normalized                0.368421
#  recency_normalized                  0.871099
#  total_spent                          4624.35
#  purchase_frequency                       181
#  unique_products                          151
#  normalized_f                        0.238095
#  normalized_r                        0.871099
#  combined_score                      0.617898
#  category_score                             1
#  business_score                      0.993691
#  score                               0.995269
#  bundle_id                   4623541_Bundle_1
#  is_anchor                                  0
#  Name: 15314, dtype: object,
#  consultant_id                        4623541
#  product_id                         200101587
#  category                          MAQUILLAJE
#  brand                                  ESIKA
#  price                                   17.9
#  date                              2022-12-27
#  frequency                                 11
#  daily_total_spent                      133.3
#  average_purchasing_power             430.195
#  recency                                  732
#  frequency_normalized                0.175439
#  recency_normalized                  0.979647
#  total_spent                          4624.35
#  purchase_frequency                       181
#  unique_products                          151
#  normalized_f                        0.238095
#  normalized_r                        0.979647
#  combined_score                      0.683026
#  bundle_id                   4623541_Bundle_2
#  is_anchor                                  1
#  Name: 4569, dtype: object,
#  consultant_id                        4623541
#  product_id                         200110649
#  category                          MAQUILLAJE
#  brand                                  ESIKA
#  price                                   24.9
#  date                              2023-05-26
#  frequency                                 16
#  daily_total_spent                      301.0
#  average_purchasing_power             430.195
#  recency                                  582
#  frequency_normalized                0.263158
#  recency_normalized                  0.776119
#  total_spent                          4624.35
#  purchase_frequency                       181
#  unique_products                          151
#  normalized_f                        0.238095
#  normalized_r                        0.776119
#  combined_score                       0.56091
#  category_score                             1
#  business_score                      0.998435
#  score                               0.998826
#  bundle_id                   4623541_Bundle_2
#  is_anchor                                  0
#  Name: 24080, dtype: object,
#  consultant_id                        4623541
#  product_id                         200100052
#  category                          MAQUILLAJE
#  brand                                  ESIKA
#  price                                   35.9
#  date                              2023-02-06
#  frequency                                 19
#  daily_total_spent                      558.3
#  average_purchasing_power             430.195
#  recency                                  691
#  frequency_normalized                0.315789
#  recency_normalized                  0.924016
#  total_spent                          4624.35
#  purchase_frequency                       181
#  unique_products                          151
#  normalized_f                        0.238095
#  normalized_r                        0.924016
#  combined_score                      0.649648
#  category_score                             1
#  business_score                      0.995374
#  score                                0.99653
#  bundle_id                   4623541_Bundle_2
#  is_anchor                                  0
#  Name: 302, dtype: object,
#  consultant_id                        4623541
#  product_id                         200103920
#  category                          MAQUILLAJE
#  brand                                 CYZONE
#  price                                   11.6
#  date                              2023-03-17
#  frequency                                 22
#  daily_total_spent                     476.75
#  average_purchasing_power             430.195
#  recency                                  652
#  frequency_normalized                0.368421
#  recency_normalized                  0.871099
#  total_spent                          4624.35
#  purchase_frequency                       181
#  unique_products                          151
#  normalized_f                        0.238095
#  normalized_r                        0.871099
#  combined_score                      0.617898
#  category_score                             1
#  business_score                      0.969871
#  score                               0.977403
#  bundle_id                   4623541_Bundle_2
#  is_anchor                                  0
#  Name: 19593, dtype: object,
#  consultant_id                        4623541
#  product_id                         200103354
#  category                          MAQUILLAJE
#  brand                                  ESIKA
#  price                                    9.0
#  date                              2023-03-17
#  frequency                                 22
#  daily_total_spent                     476.75
#  average_purchasing_power             430.195
#  recency                                  652
#  frequency_normalized                0.368421
#  recency_normalized                  0.871099
#  total_spent                          4624.35
#  purchase_frequency                       181
#  unique_products                          151
#  normalized_f                        0.238095
#  normalized_r                        0.871099
#  combined_score                      0.617898
#  category_score                             1
#  business_score                      0.057457
#  score                               0.293093
#  bundle_id                   4623541_Bundle_2
#  is_anchor                                  0
#  Name: 11083, dtype: object,
#  consultant_id                        4623541
#  product_id                         200101587
#  category                          MAQUILLAJE
#  brand                                  ESIKA
#  price                                   17.9
#  date                              2022-12-27
#  frequency                                 11
#  daily_total_spent                      133.3
#  average_purchasing_power             430.195
#  recency                                  732
#  frequency_normalized                0.175439
#  recency_normalized                  0.979647
#  total_spent                          4624.35
#  purchase_frequency                       181
#  unique_products                          151
#  normalized_f                        0.238095
#  normalized_r                        0.979647
#  combined_score                      0.683026
#  bundle_id                   4623541_Bundle_3
#  is_anchor                                  1
#  Name: 4569, dtype: object,
#  consultant_id                        4623541
#  product_id                         200107183
#  category                          MAQUILLAJE
#  brand                                 CYZONE
#  price                                   14.9
#  date                              2023-07-10
#  frequency                                 12
#  daily_total_spent                      367.0
#  average_purchasing_power             430.195
#  recency                                  537
#  frequency_normalized                0.192982
#  recency_normalized                  0.715061
#  total_spent                          4624.35
#  purchase_frequency                       181
#  unique_products                          151
#  normalized_f                        0.238095
#  normalized_r                        0.715061
#  combined_score                      0.524275
#  category_score                             1
#  business_score                       0.97198
#  score                               0.978985
#  bundle_id                   4623541_Bundle_3
#  is_anchor                                  0
#  Name: 9558, dtype: object,
#  consultant_id                        4623541
#  product_id                         200112062
#  category                          MAQUILLAJE
#  brand                                   LBEL
#  price                                   57.0
#  date                              2023-07-10
#  frequency                                 12
#  daily_total_spent                      367.0
#  average_purchasing_power             430.195
#  recency                                  537
#  frequency_normalized                0.192982
#  recency_normalized                  0.715061
#  total_spent                          4624.35
#  purchase_frequency                       181
#  unique_products                          151
#  normalized_f                        0.238095
#  normalized_r                        0.715061
#  combined_score                      0.524275
#  category_score                             1
#  business_score                      0.960742
#  score                               0.970556
#  bundle_id                   4623541_Bundle_3
#  is_anchor                                  0
#  Name: 18906, dtype: object,
#  consultant_id                        4623541
#  product_id                         200103354
#  category                          MAQUILLAJE
#  brand                                  ESIKA
#  price                                    9.0
#  date                              2023-03-17
#  frequency                                 22
#  daily_total_spent                     476.75
#  average_purchasing_power             430.195
#  recency                                  652
#  frequency_normalized                0.368421
#  recency_normalized                  0.871099
#  total_spent                          4624.35
#  purchase_frequency                       181
#  unique_products                          151
#  normalized_f                        0.238095
#  normalized_r                        0.871099
#  combined_score                      0.617898
#  category_score                             1
#  business_score                      0.470563
#  score                               0.602922
#  bundle_id                   4623541_Bundle_3
#  is_anchor                                  0
#  Name: 11083, dtype: object,
#  consultant_id                        4623541
#  product_id                         200101587
#  category                          MAQUILLAJE
#  brand                                  ESIKA
#  price                                   17.9
#  date                              2022-12-27
#  frequency                                 11
#  daily_total_spent                      133.3
#  average_purchasing_power             430.195
#  recency                                  732
#  frequency_normalized                0.175439
#  recency_normalized                  0.979647
#  total_spent                          4624.35
#  purchase_frequency                       181
#  unique_products                          151
#  normalized_f                        0.238095
#  normalized_r                        0.979647
#  combined_score                      0.683026
#  bundle_id                   4623541_Bundle_4
#  is_anchor                                  1
#  Name: 4569, dtype: object,
#  consultant_id                        4623541
#  product_id                         200103727
#  category                          MAQUILLAJE
#  brand                                  ESIKA
#  price                                   26.9
#  date                              2023-04-08
#  frequency                                 19
#  daily_total_spent                      564.4
#  average_purchasing_power             430.195
#  recency                                  630
#  frequency_normalized                0.315789
#  recency_normalized                  0.841248
#  total_spent                          4624.35
#  purchase_frequency                       181
#  unique_products                          151
#  normalized_f                        0.238095
#  normalized_r                        0.841248
#  combined_score                      0.599987
#  category_score                             1
#  business_score                      0.992462
#  score                               0.994346
#  bundle_id                   4623541_Bundle_4
#  is_anchor                                  0
#  Name: 6621, dtype: object,
#  consultant_id                        4623541
#  product_id                         210095652
#  category                          MAQUILLAJE
#  brand                                 CYZONE
#  price                                   25.9
#  date                              2023-06-16
#  frequency                                 14
#  daily_total_spent                      507.6
#  average_purchasing_power             430.195
#  recency                                  561
#  frequency_normalized                 0.22807
#  recency_normalized                  0.747626
#  total_spent                          4624.35
#  purchase_frequency                       181
#  unique_products                          151
#  normalized_f                        0.238095
#  normalized_r                        0.747626
#  combined_score                      0.543813
#  category_score                             1
#  business_score                      0.985676
#  score                               0.989257
#  bundle_id                   4623541_Bundle_4
#  is_anchor                                  0
#  Name: 14789, dtype: object,
#  consultant_id                        4623541
#  product_id                         200106604
#  category                          MAQUILLAJE
#  brand                                 CYZONE
#  price                                   15.9
#  date                              2023-04-28
#  frequency                                 12
#  daily_total_spent                      483.9
#  average_purchasing_power             430.195
#  recency                                  610
#  frequency_normalized                0.192982
#  recency_normalized                  0.814111
#  total_spent                          4624.35
#  purchase_frequency                       181
#  unique_products                          151
#  normalized_f                        0.238095
#  normalized_r                        0.814111
#  combined_score                      0.583705
#  category_score                             1
#  business_score                      0.985382
#  score                               0.989036
#  bundle_id                   4623541_Bundle_4
#  is_anchor                                  0
#  Name: 11093, dtype: object,
#  consultant_id                        4623541
#  product_id                         200102092
#  category                          MAQUILLAJE
#  brand                                 CYZONE
#  price                                   11.9
#  date                              2023-01-20
#  frequency                                 24
#  daily_total_spent                      457.7
#  average_purchasing_power             430.195
#  recency                                  708
#  frequency_normalized                0.403509
#  recency_normalized                  0.947083
#  total_spent                          4624.35
#  purchase_frequency                       181
#  unique_products                          151
#  normalized_f                        0.238095
#  normalized_r                        0.947083
#  combined_score                      0.663488
#  category_score                             1
#  business_score                      0.950011
#  score                               0.962508
#  bundle_id                   4623541_Bundle_4
#  is_anchor                                  0
#  Name: 10080, dtype: object,
#  consultant_id                            8351554
#  product_id                             200089498
#  category                    TRATAMIENTO CORPORAL
#  brand                                      ESIKA
#  price                                       35.9
#  date                                  2023-05-26
#  frequency                                     14
#  daily_total_spent                          364.9
#  average_purchasing_power                 430.195
#  recency                                      582
#  frequency_normalized                     0.22807
#  recency_normalized                      0.776119
#  total_spent                              15202.7
#  purchase_frequency                           478
#  unique_products                              309
#  normalized_f                            0.630952
#  normalized_r                            0.776119
#  combined_score                          0.718053
#  bundle_id                       8351554_Bundle_1
#  is_anchor                                      1
#  Name: 1870, dtype: object,
#  consultant_id                            8351554
#  product_id                             200105178
#  category                    TRATAMIENTO CORPORAL
#  brand                                      ESIKA
#  price                                       26.9
# ...
#  average_purchasing_power              430.195
#  recency                                   688
#  frequency_normalized                 0.280702
#  recency_normalized                   0.919946
#  total_spent                           4548.33
#  purchase_frequency                        159
#  unique_products                           125
#  normalized_f                         0.208995
#  normalized_r                         0.919946
#  combined_score                       0.635565
#  category_score                              1
#  business_score                       0.923029
#  score                                0.942272
#  bundle_id                   44109905_Bundle_2
#  is_anchor                                   0
#  Name: 27183, dtype: object,
#  consultant_id                        44109905
#  product_id                          200095162
#  category                     CUIDADO PERSONAL
#  brand                                   ESIKA
#  price                                    5.36
#  date                               2023-02-09
#  frequency                                  17
#  daily_total_spent                       427.4
#  average_purchasing_power              430.195
#  recency                                   688
#  frequency_normalized                 0.280702
#  recency_normalized                   0.919946
#  total_spent                           4548.33
#  purchase_frequency                        159
#  unique_products                           125
#  normalized_f                         0.208995
#  normalized_r                         0.919946
#  combined_score                       0.635565
#  category_score                              1
#  business_score                       0.897193
#  score                                0.922895
#  bundle_id                   44109905_Bundle_2
#  is_anchor                                   0
#  Name: 2239, dtype: object,
#  consultant_id                        44109905
#  product_id                          200105125
#  category                     CUIDADO PERSONAL
#  brand                                   ESIKA
#  price                                    11.9
#  date                               2023-03-23
#  frequency                                  21
#  daily_total_spent                       405.1
#  average_purchasing_power              430.195
#  recency                                   646
#  frequency_normalized                 0.350877
#  recency_normalized                   0.862958
#  total_spent                           4548.33
#  purchase_frequency                        159
#  unique_products                           125
#  normalized_f                         0.208995
#  normalized_r                         0.862958
#  combined_score                       0.601373
#  category_score                              1
#  business_score                       0.880436
#  score                                0.910327
#  bundle_id                   44109905_Bundle_2
#  is_anchor                                   0
#  Name: 33409, dtype: object,
#  consultant_id                        44109905
#  product_id                          200105190
#  category                     CUIDADO PERSONAL
#  brand                                   ESIKA
#  price                                    11.9
#  date                               2023-07-10
#  frequency                                   9
#  daily_total_spent                       276.1
#  average_purchasing_power              430.195
#  recency                                   537
#  frequency_normalized                 0.140351
#  recency_normalized                   0.715061
#  total_spent                           4548.33
#  purchase_frequency                        159
#  unique_products                           125
#  normalized_f                         0.208995
#  normalized_r                         0.715061
#  combined_score                       0.512635
#  category_score                              1
#  business_score                       0.832229
#  score                                0.874172
#  bundle_id                   44109905_Bundle_2
#  is_anchor                                   0
#  Name: 24927, dtype: object,
#  consultant_id                        44109905
#  product_id                          200095162
#  category                     CUIDADO PERSONAL
#  brand                                   ESIKA
#  price                                     5.2
#  date                               2023-03-23
#  frequency                                  21
#  daily_total_spent                       405.1
#  average_purchasing_power              430.195
#  recency                                   646
#  frequency_normalized                 0.350877
#  recency_normalized                   0.862958
#  total_spent                           4548.33
#  purchase_frequency                        159
#  unique_products                           125
#  normalized_f                         0.208995
#  normalized_r                         0.862958
#  combined_score                       0.601373
#  category_score                              1
#  business_score                       0.778408
#  score                                0.833806
#  bundle_id                   44109905_Bundle_2
#  is_anchor                                   0
#  Name: 16119, dtype: object,
#  consultant_id                        44109905
#  product_id                          200103025
#  category                     CUIDADO PERSONAL
#  brand                                   ESIKA
#  price                                    29.9
#  date                               2022-12-27
#  frequency                                  11
#  daily_total_spent                       256.6
#  average_purchasing_power              430.195
#  recency                                   732
#  frequency_normalized                 0.175439
#  recency_normalized                   0.979647
#  total_spent                           4548.33
#  purchase_frequency                        159
#  unique_products                           125
#  normalized_f                         0.208995
#  normalized_r                         0.979647
#  combined_score                       0.671386
#  bundle_id                   44109905_Bundle_3
#  is_anchor                                   1
#  Name: 4600, dtype: object,
#  consultant_id                        44109905
#  product_id                          200095170
#  category                     CUIDADO PERSONAL
#  brand                                   ESIKA
#  price                                    11.9
#  date                               2023-05-05
#  frequency                                  16
#  daily_total_spent                      496.65
#  average_purchasing_power              430.195
#  recency                                   603
#  frequency_normalized                 0.263158
#  recency_normalized                   0.804613
#  total_spent                           4548.33
#  purchase_frequency                        159
#  unique_products                           125
#  normalized_f                         0.208995
#  normalized_r                         0.804613
#  combined_score                       0.566366
#  category_score                              1
#  business_score                       0.996755
#  score                                0.997566
#  bundle_id                   44109905_Bundle_3
#  is_anchor                                   0
#  Name: 19982, dtype: object,
#  consultant_id                        44109905
#  product_id                          210100408
#  category                     CUIDADO PERSONAL
#  brand                                  CYZONE
#  price                                   14.95
#  date                               2023-05-05
#  frequency                                  16
#  daily_total_spent                      496.65
#  average_purchasing_power              430.195
#  recency                                   603
#  frequency_normalized                 0.263158
#  recency_normalized                   0.804613
#  total_spent                           4548.33
#  purchase_frequency                        159
#  unique_products                           125
#  normalized_f                         0.208995
#  normalized_r                         0.804613
#  combined_score                       0.566366
#  category_score                              1
#  business_score                       0.923907
#  score                                 0.94293
#  bundle_id                   44109905_Bundle_3
#  is_anchor                                   0
#  Name: 58, dtype: object,
#  consultant_id                        44109905
#  product_id                          200108807
#  category                     CUIDADO PERSONAL
#  brand                                   ESIKA
#  price                                    11.9
#  date                               2023-03-23
#  frequency                                  21
#  daily_total_spent                       405.1
#  average_purchasing_power              430.195
#  recency                                   646
#  frequency_normalized                 0.350877
#  recency_normalized                   0.862958
#  total_spent                           4548.33
#  purchase_frequency                        159
#  unique_products                           125
#  normalized_f                         0.208995
#  normalized_r                         0.862958
#  combined_score                       0.601373
#  category_score                              1
#  business_score                       0.918691
#  score                                0.939018
#  bundle_id                   44109905_Bundle_3
#  is_anchor                                   0
#  Name: 29038, dtype: object,
#  consultant_id                        44109905
#  product_id                          200084777
#  category                     CUIDADO PERSONAL
#  brand                                  CYZONE
#  price                                    13.9
#  date                               2023-05-29
#  frequency                                   8
#  daily_total_spent                       240.2
#  average_purchasing_power              430.195
#  recency                                   579
#  frequency_normalized                 0.122807
#  recency_normalized                   0.772049
#  total_spent                           4548.33
#  purchase_frequency                        159
#  unique_products                           125
#  normalized_f                         0.208995
#  normalized_r                         0.772049
#  combined_score                       0.546827
#  category_score                              1
#  business_score                       0.906549
#  score                                0.929912
#  bundle_id                   44109905_Bundle_3
#  is_anchor                                   0
#  Name: 20156, dtype: object,
#  consultant_id                        44109905
#  product_id                          210100407
#  category                     CUIDADO PERSONAL
#  brand                                  CYZONE
#  price                                   14.95
#  date                               2023-05-05
#  frequency                                  16
#  daily_total_spent                      496.65
#  average_purchasing_power              430.195
#  recency                                   603
#  frequency_normalized                 0.263158
#  recency_normalized                   0.804613
#  total_spent                           4548.33
#  purchase_frequency                        159
#  unique_products                           125
#  normalized_f                         0.208995
#  normalized_r                         0.804613
#  combined_score                       0.566366
#  category_score                              1
#  business_score                       0.867261
#  score                                0.900446
#  bundle_id                   44109905_Bundle_3
#  is_anchor                                   0
#  Name: 9363, dtype: object,
#  consultant_id                        44109905
#  product_id                          200103025
#  category                     CUIDADO PERSONAL
#  brand                                   ESIKA
#  price                                    29.9
#  date                               2022-12-27
#  frequency                                  11
#  daily_total_spent                       256.6
#  average_purchasing_power              430.195
#  recency                                   732
#  frequency_normalized                 0.175439
#  recency_normalized                   0.979647
#  total_spent                           4548.33
#  purchase_frequency                        159
#  unique_products                           125
#  normalized_f                         0.208995
#  normalized_r                         0.979647
#  combined_score                       0.671386
#  bundle_id                   44109905_Bundle_4
#  is_anchor                                   1
#  Name: 4600, dtype: object,
#  consultant_id                        44109905
#  product_id                          210095249
#  category                     CUIDADO PERSONAL
#  brand                                  CYZONE
#  price                                   16.45
#  date                               2023-04-13
#  frequency                                   8
#  daily_total_spent                       167.3
#  average_purchasing_power              430.195
#  recency                                   625
#  frequency_normalized                 0.122807
#  recency_normalized                   0.834464
#  total_spent                           4548.33
#  purchase_frequency                        159
#  unique_products                           125
#  normalized_f                         0.208995
#  normalized_r                         0.834464
#  combined_score                       0.584276
#  category_score                              1
#  business_score                        0.88447
#  score                                0.913353
#  bundle_id                   44109905_Bundle_4
#  is_anchor                                   0
#  Name: 29222, dtype: object,
#  consultant_id                        44109905
#  product_id                          200105655
#  category                     CUIDADO PERSONAL
#  brand                                   ESIKA
#  price                                    24.9
#  date                               2023-03-23
#  frequency                                  21
#  daily_total_spent                       405.1
#  average_purchasing_power              430.195
#  recency                                   646
#  frequency_normalized                 0.350877
#  recency_normalized                   0.862958
#  total_spent                           4548.33
#  purchase_frequency                        159
#  unique_products                           125
#  normalized_f                         0.208995
#  normalized_r                         0.862958
#  combined_score                       0.601373
#  category_score                              1
#  business_score                       0.862415
#  score                                0.896812
#  bundle_id                   44109905_Bundle_4
#  is_anchor                                   0
#  Name: 10438, dtype: object,
#  consultant_id                        44109905
#  product_id                          200095170
#  category                     CUIDADO PERSONAL
#  brand                                   ESIKA
#  price                                    11.9
#  date                               2023-05-05
#  frequency                                  16
#  daily_total_spent                      496.65
#  average_purchasing_power              430.195
#  recency                                   603
#  frequency_normalized                 0.263158
#  recency_normalized                   0.804613
#  total_spent                           4548.33
#  purchase_frequency                        159
#  unique_products                           125
#  normalized_f                         0.208995
#  normalized_r                         0.804613
#  combined_score                       0.566366
#  category_score                              1
#  business_score                       0.833415
#  score                                0.875062
#  bundle_id                   44109905_Bundle_4
#  is_anchor                                   0
#  Name: 19982, dtype: object,
#  ...]

# %%
data = pd.DataFrame(bundles)
data.head()
# Out:
#        consultant_id  product_id          category  brand  price        date  \
# 1793         3441296   200095159  CUIDADO PERSONAL  ESIKA   7.38  2022-12-27
# 4744         3441296   200108807  CUIDADO PERSONAL  ESIKA   7.38  2022-12-27
# 22714        3441296   200095465  CUIDADO PERSONAL  ESIKA  11.90  2023-06-08
# 9107         3441296   200103025  CUIDADO PERSONAL  ESIKA  24.98  2023-08-15
# 20479        3441296   200115451  CUIDADO PERSONAL  ESIKA  18.30  2024-03-20
#
#        frequency  daily_total_spent  average_purchasing_power  recency  ...  \
# 1793          10             263.40                   430.195      732  ...
# 4744          10             263.40                   430.195      732  ...
# 22714         16             385.90                   430.195      569  ...
# 9107          11             156.66                   430.195      501  ...
# 20479          7             183.50                   430.195      283  ...
#
#        purchase_frequency  unique_products  normalized_f  normalized_r  \
# 1793                  261              194      0.343915      0.979647
# 4744                  261              194      0.343915      0.979647
# 22714                 261              194      0.343915      0.758480
# 9107                  261              194      0.343915      0.666214
# 20479                 261              194      0.343915      0.370421
#
#        combined_score         bundle_id  is_anchor  category_score  \
# 1793         0.725354  3441296_Bundle_1          1             NaN
# 4744         0.725354  3441296_Bundle_1          0             1.0
# 22714        0.592654  3441296_Bundle_1          0             1.0
# 9107         0.537295  3441296_Bundle_1          0             1.0
# 20479        0.359819  3441296_Bundle_1          0             1.0
#
#       business_score     score
# 1793             NaN       NaN
# 4744        0.921432  0.941074
# 22714       0.897779  0.923334
# 9107        0.883350  0.912513
# 20479       0.879163  0.909372
#
# [5 rows x 23 columns]

# %%
data.to_csv('bundels_data_1000_C.csv', index=False)
